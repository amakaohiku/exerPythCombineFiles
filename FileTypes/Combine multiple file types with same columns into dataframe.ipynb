# %%
# Have user select excel sheet with needed data.
import tkinter as tk
from tkinter import filedialog

root = tk.Tk()
root.lift()
root.withdraw()

# This code block will open a specific file. (Uncomment the lines after this comment to use them.)
print('Opening dialogue box for file selection. Please choose a file.')
file_path = filedialog.askopenfilename()
print('File selected:')

# This code block will get a directory path. (Uncomment the lines after this comment to use them.)
print('Opening dialogue box for folder selection. Please choose a folder.')
file_path = filedialog.askdirectory()
print('Folder selected:')

print(file_path)
# Out:
# Opening dialogue box for file selection. Please choose a file.
# File selected:
# Opening dialogue box for folder selection. Please choose a folder.
# Folder selected:
# /Users/nwamakaohiku/Desktop/6806/exerPythCombineFiles/FileTypes/FileTypes

# %%
# Make sure correct files are recognized.

import os
import pandas as pd

# List the files in the directory.
files = os.listdir(file_path)
print(files)

# List of file types we want to add
file_types = ['xlsx','csv','json','xml']

# create a list of files for each file type
files_csv = [f for f in files if f[-3:] == 'csv']
files_xlsx = [f for f in files if f[-4:] == 'xlsx']
files_json = [f for f in files if f[-4:] == 'json']
files_xml = [f for f in files if f[-3:] == 'xml']

print(files_csv, files_xlsx, files_json, files_xml)
# Out:
# ['EXCELtest2.xlsx', 'CSVtest2.csv', 'CSVtest2mod.csv', 'JSONtest3mod.json', 'JSONtest2mod.json', 'EXCELtestmod.xlsx', '.DS_Store', 'XMLtest3mod.xml', 'EXCELtest.xlsx', 'XMLtest2.xml', 'XMLtest3.xml', 'JSONtest.json', 'JSONtest2.json', 'EXCELtest2mod.xlsx', 'CSVtest.csv', 'JSONtest3.json', 'Combine multiple file types with same columns into dataframe.py', 'XMLtest2mod.xml', 'XMLtestmod.xml', 'JSONtestmod.json', 'XMLtest.xml', 'CSVtestmod.csv']
# ['CSVtest2.csv', 'CSVtest2mod.csv', 'CSVtest.csv', 'CSVtestmod.csv'] ['EXCELtest2.xlsx', 'EXCELtestmod.xlsx', 'EXCELtest.xlsx', 'EXCELtest2mod.xlsx'] ['JSONtest3mod.json', 'JSONtest2mod.json', 'JSONtest.json', 'JSONtest2.json', 'JSONtest3.json', 'JSONtestmod.json'] ['XMLtest3mod.xml', 'XMLtest2.xml', 'XMLtest3.xml', 'XMLtest2mod.xml', 'XMLtestmod.xml', 'XMLtest.xml']

# %%
import json
import requests 
import xml.etree.ElementTree as ET

# Iterate through the files in the directory and append each one into the dataframe.
# This will only work correctly if the files have the exact same column names.
df_list = []
for f in files_csv:
    data = pd.read_csv(str(file_path) + '/' + str(f), index_col=None, header=0)
    data['Source'] = f
    df_list.append(data)
    
for f in files_xlsx:
    data = pd.read_excel(str(file_path) + '/' + str(f))
    data['Source'] = f
    df_list.append(data)
    
# Iterate through the json files and add data from each to a list.
json_list = []
for f in files_json:
    with open(str(file_path) + '/' + str(f)) as json_file:
        json_obj = json.load(json_file)
        json_obj['Source'] = f
        json_list.append(json_obj.copy())
# Turn the combined list into a dataframe.
data = pd.DataFrame(json_list)
# Add the data frame to the list of dataframes.
df_list.append(data)
    
# Iterate through the xml files and add data from each to a list.
xml_list = []
for f in files_xml:
    # create element tree object 
    tree = ET.parse(str(file_path) + '/' + str(f))
    # get root element 
    root = tree.getroot()
    # create dictionary from XML tags and values
    itemdict = {}
    for item in root:
        itemdict[item.tag] = item.text
    itemdict['Source'] = f
    xml_list.append(itemdict.copy())
# Turn the combined list into a dataframe.
data = pd.DataFrame(xml_list)
# Add the data frame to the list of dataframes.
df_list.append(data)

# Combine all the data frames in the list into a single data frame.    
df =  pd.concat(df_list, axis=0, ignore_index=True, sort=False)

# See how many rows the data frame has.
print(len(df.index))

# Show the data in the data frame.
df
# Out:
# 28
#              name                 date height weight              Source
# 0    Brock Bricks            4/10/2019    185     95        CSVtest2.csv
# 1      Jack Brack             6/7/2019    172     91        CSVtest2.csv
# 2    Brock Bricks              4/10/19    185     95     CSVtest2mod.csv
# 3      Jack Brack               6/7/19    172     91     CSVtest2mod.csv
# 4      Jack Smith             4/1/2019    185     91         CSVtest.csv
# 5      Jack Black             4/2/2019    183     91         CSVtest.csv
# 6      Jack Smith               4/1/19    185     91      CSVtestmod.csv
# 7      Jack Black               4/2/19    283     91      CSVtestmod.csv
# 8     Rock Royden  2019-05-02 00:00:00    160     52     EXCELtest2.xlsx
# 9   Brandon Snads  2019-10-02 00:00:00    175     80     EXCELtest2.xlsx
# 10      Jen Smith  2019-05-02 00:00:00    153     50   EXCELtestmod.xlsx
# 11      Sam Smith  2019-01-02 00:00:00    160     60   EXCELtestmod.xlsx
# 12      Jen Smith  2019-05-02 00:00:00    153     50      EXCELtest.xlsx
# 13      Sam Smith  2019-01-02 00:00:00    160     55      EXCELtest.xlsx
# 14    Rock Royden  2019-05-02 00:00:00    160     52  EXCELtest2mod.xlsx
# 15  Brandon Snads  2019-10-02 00:00:00    324     80  EXCELtest2mod.xlsx
# 16  Becky Jackson           04/03/2020    165     70   JSONtest3mod.json
# 17   Jane Jackson           09/03/2019    172     80   JSONtest2mod.json
# 18     Jane Smith           09/02/2019    170     75       JSONtest.json
# 19   Jane Jackson           09/03/2019    172     74      JSONtest2.json
# 20  Becky Jackson           04/03/2019    165     70      JSONtest3.json
# 21     Jane Smith           09/02/2019    180     75    JSONtestmod.json
# 22   Brett Smithe           05/08/2019    179    991     XMLtest3mod.xml
# 23    John Smithe           03/08/2019    185    101        XMLtest2.xml
# 24   Brett Smithe           05/08/2019    179     99        XMLtest3.xml
# 25    John Smithe           03/08/2019    185    120     XMLtest2mod.xml
# 26     John Smith           02/08/2019    190    100      XMLtestmod.xml
# 27     John Smith           02/08/2019    180    100         XMLtest.xml

# %%
# Save the dataframe to a new combined csv file.

# Add today's date to the name of the new file.
from datetime import date
today = date.today()
print(today)

filename = str(file_path) + '/' + 'NewCombinedFile_' + str(today) + '.csv'
print(filename)

df.to_csv(filename, index=False)
print('File saved.')
# Out:
# 2020-11-14
# /Users/nwamakaohiku/Desktop/6806/exerPythCombineFiles/FileTypes/FileTypes/NewCombinedFile_2020-11-14.csv
# File saved.
